# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import os

import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
import torchaudio
import torchmetrics
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset

from waveform_encoder import WaveformEncoder

# %%
TRAIN_DIR_PATH = 'voice-commands-classification-2025/train'
TEST_DIR_PATH = 'voice-commands-classification-2025/adv_test'

# %%
BATCH_SIZE = 512
N_WORKERS = 6
N_CLASSES = 35
EPOCHS = 50
LR = 0.01

N_MFCC = 120
NOISE_AMPLITUDE = 0.000
MASK_PROB = 0.1

DEVICE = torch.device('cpu')
if torch.cuda.is_available():
    DEVICE = torch.device('cuda:0')
elif torch.backends.mps.is_available():
    DEVICE = torch.device('mps')

DEVICE
# Out:
# device(type='cuda', index=0)

# %%
# Dataset

def noise_waveform(waveform: torch.Tensor, noise_amplitude: float = 0.05) -> torch.Tensor:
    noise = noise_amplitude * torch.randn(waveform.shape).to(waveform.device)
    noisy_waveform = waveform + noise
    noisy_waveform = torch.clamp(noisy_waveform, -1.0, 1.0)
    return noisy_waveform

class SpeechCommandDataset(Dataset):
    def __init__(self, dir_path, data, labels=None, dict_label_to_index=None, transform=None, noise_amplitude=0.00):
        self.dir_path = dir_path
        self.data = data
        self.labels = labels
        self.dict_label_to_index = dict_label_to_index
        self.transform = transform
        self.noise_amplitude = noise_amplitude

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        file_name = self.data[idx]
        waveform = np.load(os.path.join(self.dir_path, file_name))
        if waveform.shape[1] < 16000:
            waveform = np.pad(
                waveform, pad_width=((0, 0), (0, 16000 - waveform.shape[1])),
                mode='constant',
                constant_values=0
            )

        waveform = torch.from_numpy(waveform).float()

        if self.transform != None:
            spectrogram = self.transform(waveform)
        else:
            spectrogram = None

        if self.noise_amplitude > 0:
            waveform = noise_waveform(waveform, self.noise_amplitude)
        
        out_labels = []
        if self.labels is not None:
            if self.labels[idx] in self.dict_label_to_index:
                out_labels = self.dict_label_to_index[self.labels[idx]]

        return waveform, spectrogram, out_labels, int(file_name.split('.')[0])

# %%
df_train = pd.read_csv(
    os.path.join(TRAIN_DIR_PATH, 'metadata.csv')
)
dict_label_to_index = {}
dict_index_to_label = {}
for index, key in enumerate(df_train['label'].unique()):
    dict_label_to_index[key] = index
    dict_index_to_label[index] = key

dict_label_to_index
# Out:
# {'stop': 0,
#  'go': 1,
#  'right': 2,
#  'dog': 3,
#  'left': 4,
#  'yes': 5,
#  'zero': 6,
#  'four': 7,
#  'bird': 8,
#  'cat': 9,
#  'five': 10,
#  'off': 11,
#  'learn': 12,
#  'six': 13,
#  'two': 14,
#  'on': 15,
#  'up': 16,
#  'three': 17,
#  'nine': 18,
#  'one': 19,
#  'follow': 20,
#  'wow': 21,
#  'seven': 22,
#  'sheila': 23,
#  'down': 24,
#  'no': 25,
#  'bed': 26,
#  'eight': 27,
#  'house': 28,
#  'tree': 29,
#  'visual': 30,
#  'forward': 31,
#  'marvin': 32,
#  'backward': 33,
#  'happy': 34}

# %%
df_train_data, df_val_data = train_test_split(
    df_train,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

train_data = df_train_data.file_name.values
train_labels = df_train_data.label.values

val_data = df_val_data.file_name.values
val_labels = df_val_data.label.values

# %%
# DataLoader, transform

train_dataloader = DataLoader(
    SpeechCommandDataset(
        dir_path=TRAIN_DIR_PATH,
        data=train_data,
        labels=train_labels,
        dict_label_to_index=dict_label_to_index,
        transform=torchaudio.transforms.MFCC(n_mfcc=N_MFCC, log_mels=True),
        noise_amplitude=NOISE_AMPLITUDE
    ),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=N_WORKERS
)

valid_dataloader = DataLoader(
    SpeechCommandDataset(
        dir_path=TRAIN_DIR_PATH,
        data=val_data,
        labels=val_labels,
        dict_label_to_index=dict_label_to_index,
        transform=torchaudio.transforms.MFCC(n_mfcc=N_MFCC, log_mels=True),
        noise_amplitude=0.0
    ),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=N_WORKERS
)

# %%
for item in train_dataloader:
    print(item[0].shape, item[1].shape)
    break
# Out:
# torch.Size([512, 1, 16000]) torch.Size([512, 1, 120, 81])

# %%
class M5(nn.Module):
    def __init__(self, n_input, n_output, stride=160, n_channel=32):
        super().__init__()
        self.wf_enc = WaveformEncoder(n_input, stride=stride, kernel_size=400, n_channel=n_channel)
        self.out = nn.Linear(n_channel, n_output)

    def forward(self, sg):
        sg = self.wf_enc(sg)
        
        sg = sg.transpose(-1, -2)
        sg = F.avg_pool1d(sg, sg.shape[-1])
        sg = sg.transpose(-1, -2)
        sg = self.out(sg)
        return F.log_softmax(sg, dim=2)

# %%
model = M5(n_input=1, n_output=35, stride=160, n_channel=N_MFCC).to(DEVICE)

# %%
input_image = torch.rand(4, 1, 16000).to(DEVICE)
model = model.to(DEVICE)
result = model(input_image)
print(result.size())
# Out:
# torch.Size([4, 1, 35])

# %%
def lr_lambda(current_step):
    return max(0.0, float(EPOCHS - current_step) / EPOCHS)


def train_model(model: nn.Module, train_data: DataLoader, valid_data: DataLoader):
    optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=2e-5)
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
    criterion = nn.NLLLoss()

    accuracy_train = torchmetrics.classification.Accuracy(task="multiclass", num_classes=N_CLASSES).to(DEVICE)
    accuracy_val = torchmetrics.classification.Accuracy(task="multiclass", num_classes=N_CLASSES).to(DEVICE)

    for epoch in range(EPOCHS):
        train_loss = 0.0
        val_loss = 0.0

        model.train()
        for x, x_sp, y, _ in train_data:
            x = x.to(DEVICE)
            x_sp = x_sp.to(DEVICE)
            y = y.to(DEVICE)

            optimizer.zero_grad()

            y_hat = model(x).squeeze()
            loss = criterion(y_hat, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item() * x.size(0)
            _, preds = torch.max(y_hat, 1)

            accuracy_train(
                y_hat,
                y
            )

        model.eval()
        for x, x_sp, y, _ in valid_data:
            x = x.to(DEVICE)
            x_sp = x_sp.to(DEVICE)
            y = y.to(DEVICE)

            y_hat = model(x).squeeze()
            loss = criterion(y_hat, y)

            val_loss += loss.item() * x.size(0)
            _, preds = torch.max(y_hat, 1)

            accuracy_val(
                y_hat,
                y
            )

        train_loss = train_loss / len(train_dataloader.dataset)
        val_loss = val_loss / len(valid_dataloader.dataset)

        scheduler.step()

        print(f"Epoch {epoch + 1}/{EPOCHS}")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {accuracy_train.compute():.4f}")
        print(f"Val Loss: {val_loss:.4f}, Val Acc: {accuracy_val.compute():.4f}")

# %%
train_model(
    model=model,
    train_data=train_dataloader,
    valid_data=valid_dataloader
)
torch.save(model.state_dict(), 'waveform_encoder_1.pt')
# Out:
# Epoch 1/50
# Train Loss: 2.3397, Train Acc: 0.3305
# Val Loss: 1.6559, Val Acc: 0.5123
# Epoch 2/50
# Train Loss: 1.2853, Train Acc: 0.4718
# Val Loss: 1.1106, Val Acc: 0.5939
# Epoch 3/50
# Train Loss: 0.9170, Train Acc: 0.5559
# Val Loss: 0.8415, Val Acc: 0.6446
# Epoch 4/50
# Train Loss: 0.7404, Train Acc: 0.6107
# Val Loss: 0.7632, Val Acc: 0.6764
# Epoch 5/50
# Train Loss: 0.6263, Train Acc: 0.6501
# Val Loss: 0.7212, Val Acc: 0.6978
# Epoch 6/50
# Train Loss: 0.5729, Train Acc: 0.6789
# Val Loss: 0.6916, Val Acc: 0.7135
# Epoch 7/50
# Train Loss: 0.5176, Train Acc: 0.7018
# Val Loss: 0.6568, Val Acc: 0.7261
# Epoch 8/50
# Train Loss: 0.4734, Train Acc: 0.7206
# Val Loss: 0.6151, Val Acc: 0.7372
# Epoch 9/50
# Train Loss: 0.4601, Train Acc: 0.7356
# Val Loss: 0.6181, Val Acc: 0.7455
# Epoch 10/50
# Train Loss: 0.4118, Train Acc: 0.7491
# Val Loss: 0.5990, Val Acc: 0.7529
# Epoch 11/50
# Train Loss: 0.3904, Train Acc: 0.7607
# Val Loss: 0.5930, Val Acc: 0.7592
# Epoch 12/50
# Train Loss: 0.3635, Train Acc: 0.7710
# Val Loss: 0.5791, Val Acc: 0.7650
# Epoch 13/50
# Train Loss: 0.3403, Train Acc: 0.7803
# Val Loss: 0.5717, Val Acc: 0.7703
# Epoch 14/50
# Train Loss: 0.3338, Train Acc: 0.7885
# Val Loss: 0.5976, Val Acc: 0.7746
# Epoch 15/50
# Train Loss: 0.2977, Train Acc: 0.7963
# Val Loss: 0.5734, Val Acc: 0.7789
# Epoch 16/50
# Train Loss: 0.2702, Train Acc: 0.8035
# Val Loss: 0.5826, Val Acc: 0.7827
# Epoch 17/50
# Train Loss: 0.2666, Train Acc: 0.8101
# Val Loss: 0.5831, Val Acc: 0.7860
# Epoch 18/50
# Train Loss: 0.2438, Train Acc: 0.8163
# Val Loss: 0.5699, Val Acc: 0.7892
# Epoch 19/50
# Train Loss: 0.2313, Train Acc: 0.8220
# Val Loss: 0.5816, Val Acc: 0.7919
# Epoch 20/50
# Train Loss: 0.2163, Train Acc: 0.8274
# Val Loss: 0.5953, Val Acc: 0.7944
# Epoch 21/50
# Train Loss: 0.1981, Train Acc: 0.8326
# Val Loss: 0.5914, Val Acc: 0.7967
# Epoch 22/50
# Train Loss: 0.1994, Train Acc: 0.8373
# Val Loss: 0.5957, Val Acc: 0.7987
# Epoch 23/50
# Train Loss: 0.2030, Train Acc: 0.8415
# Val Loss: 0.6230, Val Acc: 0.8004
# Epoch 24/50
# Train Loss: 0.1746, Train Acc: 0.8458
# Val Loss: 0.6000, Val Acc: 0.8024
# Epoch 25/50
# Train Loss: 0.1456, Train Acc: 0.8501
# Val Loss: 0.6078, Val Acc: 0.8043
# Epoch 26/50
# Train Loss: 0.1386, Train Acc: 0.8541
# Val Loss: 0.6048, Val Acc: 0.8061
# Epoch 27/50
# Train Loss: 0.1233, Train Acc: 0.8581
# Val Loss: 0.6489, Val Acc: 0.8077
# Epoch 28/50
# Train Loss: 0.1157, Train Acc: 0.8618
# Val Loss: 0.6215, Val Acc: 0.8094
# Epoch 29/50
# Train Loss: 0.1042, Train Acc: 0.8654
# Val Loss: 0.6444, Val Acc: 0.8109
# Epoch 30/50
# Train Loss: 0.0949, Train Acc: 0.8689
# Val Loss: 0.6629, Val Acc: 0.8123
# Epoch 31/50
# Train Loss: 0.0938, Train Acc: 0.8722
# Val Loss: 0.6866, Val Acc: 0.8135
# Epoch 32/50
# Train Loss: 0.0838, Train Acc: 0.8753
# Val Loss: 0.6698, Val Acc: 0.8148
# Epoch 33/50
# Train Loss: 0.0692, Train Acc: 0.8785
# Val Loss: 0.6765, Val Acc: 0.8161
# Epoch 34/50
# Train Loss: 0.0558, Train Acc: 0.8816
# Val Loss: 0.7174, Val Acc: 0.8173
# Epoch 35/50
# Train Loss: 0.0500, Train Acc: 0.8845
# Val Loss: 0.7062, Val Acc: 0.8184
# Epoch 36/50
# Train Loss: 0.0409, Train Acc: 0.8874
# Val Loss: 0.7269, Val Acc: 0.8195
# Epoch 37/50
# Train Loss: 0.0425, Train Acc: 0.8901
# Val Loss: 0.7435, Val Acc: 0.8205
# Epoch 38/50
# Train Loss: 0.0386, Train Acc: 0.8927
# Val Loss: 0.7435, Val Acc: 0.8215
# Epoch 39/50
# Train Loss: 0.0294, Train Acc: 0.8953
# Val Loss: 0.7456, Val Acc: 0.8225
# Epoch 40/50
# Train Loss: 0.0219, Train Acc: 0.8978
# Val Loss: 0.7420, Val Acc: 0.8236
# Epoch 41/50
# Train Loss: 0.0186, Train Acc: 0.9002
# Val Loss: 0.7755, Val Acc: 0.8246
# Epoch 42/50
# Train Loss: 0.0134, Train Acc: 0.9025
# Val Loss: 0.7743, Val Acc: 0.8255
# Epoch 43/50
# Train Loss: 0.0113, Train Acc: 0.9047
# Val Loss: 0.7942, Val Acc: 0.8264
# Epoch 44/50
# Train Loss: 0.0110, Train Acc: 0.9068
# Val Loss: 0.7930, Val Acc: 0.8273
# Epoch 45/50
# Train Loss: 0.0096, Train Acc: 0.9088
# Val Loss: 0.7987, Val Acc: 0.8281
# Epoch 46/50
# Train Loss: 0.0082, Train Acc: 0.9108
# Val Loss: 0.8188, Val Acc: 0.8289
# Epoch 47/50
# Train Loss: 0.0075, Train Acc: 0.9127
# Val Loss: 0.8167, Val Acc: 0.8296
# Epoch 48/50
# Train Loss: 0.0068, Train Acc: 0.9144
# Val Loss: 0.8305, Val Acc: 0.8303
# Epoch 49/50
# Train Loss: 0.0059, Train Acc: 0.9162
# Val Loss: 0.8331, Val Acc: 0.8309
# Epoch 50/50
# Train Loss: 0.0054, Train Acc: 0.9178
# Val Loss: 0.8403, Val Acc: 0.8315

# %%
train_model(
    model=model,
    train_data=train_dataloader,
    valid_data=valid_dataloader
)
torch.save(model.state_dict(), 'waveform_encoder_2.pt')
# Out:
# Epoch 1/50
# Train Loss: 0.3769, Train Acc: 0.8847
# Val Loss: 0.6035, Val Acc: 0.8340
# Epoch 2/50
# Train Loss: 0.2919, Train Acc: 0.8953
# Val Loss: 0.6378, Val Acc: 0.8303
# Epoch 3/50
# Train Loss: 0.3055, Train Acc: 0.8974
# Val Loss: 0.5844, Val Acc: 0.8325
# Epoch 4/50
# Train Loss: 0.2746, Train Acc: 0.9010
# Val Loss: 0.5613, Val Acc: 0.8345
# Epoch 5/50
# Train Loss: 0.2684, Train Acc: 0.9034
# Val Loss: 0.5738, Val Acc: 0.8360
# Epoch 6/50
# Train Loss: 0.2568, Train Acc: 0.9057
# Val Loss: 0.5781, Val Acc: 0.8368
# Epoch 7/50
# Train Loss: 0.2467, Train Acc: 0.9075
# Val Loss: 0.5614, Val Acc: 0.8382
# Epoch 8/50
# Train Loss: 0.2359, Train Acc: 0.9096
# Val Loss: 0.5866, Val Acc: 0.8390
# Epoch 9/50
# Train Loss: 0.2284, Train Acc: 0.9114
# Val Loss: 0.5762, Val Acc: 0.8394
# Epoch 10/50
# Train Loss: 0.2186, Train Acc: 0.9131
# Val Loss: 0.5801, Val Acc: 0.8401
# Epoch 11/50
# Train Loss: 0.2018, Train Acc: 0.9151
# Val Loss: 0.5679, Val Acc: 0.8408
# Epoch 12/50
# Train Loss: 0.2086, Train Acc: 0.9166
# Val Loss: 0.5632, Val Acc: 0.8414
# Epoch 13/50
# Train Loss: 0.1936, Train Acc: 0.9182
# Val Loss: 0.5909, Val Acc: 0.8421
# Epoch 14/50
# Train Loss: 0.1799, Train Acc: 0.9198
# Val Loss: 0.5784, Val Acc: 0.8425
# Epoch 15/50
# Train Loss: 0.1705, Train Acc: 0.9214
# Val Loss: 0.5862, Val Acc: 0.8431
# Epoch 16/50
# Train Loss: 0.1631, Train Acc: 0.9230
# Val Loss: 0.5756, Val Acc: 0.8439
# Epoch 17/50
# Train Loss: 0.1526, Train Acc: 0.9247
# Val Loss: 0.5828, Val Acc: 0.8445
# Epoch 18/50
# Train Loss: 0.1453, Train Acc: 0.9263
# Val Loss: 0.5908, Val Acc: 0.8451
# Epoch 19/50
# Train Loss: 0.1423, Train Acc: 0.9277
# Val Loss: 0.5764, Val Acc: 0.8457
# Epoch 20/50
# Train Loss: 0.1188, Train Acc: 0.9294
# Val Loss: 0.6028, Val Acc: 0.8463
# Epoch 21/50
# Train Loss: 0.1088, Train Acc: 0.9311
# Val Loss: 0.6080, Val Acc: 0.8469
# Epoch 22/50
# Train Loss: 0.1111, Train Acc: 0.9326
# Val Loss: 0.6187, Val Acc: 0.8471
# Epoch 23/50
# Train Loss: 0.1117, Train Acc: 0.9339
# Val Loss: 0.6036, Val Acc: 0.8476
# Epoch 24/50
# Train Loss: 0.0883, Train Acc: 0.9355
# Val Loss: 0.6380, Val Acc: 0.8480
# Epoch 25/50
# Train Loss: 0.0847, Train Acc: 0.9370
# Val Loss: 0.6325, Val Acc: 0.8485
# Epoch 26/50
# Train Loss: 0.0797, Train Acc: 0.9385
# Val Loss: 0.6353, Val Acc: 0.8490
# Epoch 27/50
# Train Loss: 0.0726, Train Acc: 0.9399
# Val Loss: 0.6869, Val Acc: 0.8492
# Epoch 28/50
# Train Loss: 0.0707, Train Acc: 0.9412
# Val Loss: 0.6462, Val Acc: 0.8497
# Epoch 29/50
# Train Loss: 0.0586, Train Acc: 0.9427
# Val Loss: 0.6854, Val Acc: 0.8501
# Epoch 30/50
# Train Loss: 0.0601, Train Acc: 0.9440
# Val Loss: 0.6698, Val Acc: 0.8505
# Epoch 31/50
# Train Loss: 0.0503, Train Acc: 0.9453
# Val Loss: 0.6924, Val Acc: 0.8509
# Epoch 32/50
# Train Loss: 0.0403, Train Acc: 0.9466
# Val Loss: 0.7013, Val Acc: 0.8513
# Epoch 33/50
# Train Loss: 0.0343, Train Acc: 0.9479
# Val Loss: 0.7243, Val Acc: 0.8517
# Epoch 34/50
# Train Loss: 0.0367, Train Acc: 0.9491
# Val Loss: 0.6854, Val Acc: 0.8521
# Epoch 35/50
# Train Loss: 0.0315, Train Acc: 0.9504
# Val Loss: 0.6841, Val Acc: 0.8525
# Epoch 36/50
# Train Loss: 0.0253, Train Acc: 0.9515
# Val Loss: 0.7150, Val Acc: 0.8529
# Epoch 37/50
# Train Loss: 0.0224, Train Acc: 0.9527
# Val Loss: 0.7094, Val Acc: 0.8533
# Epoch 38/50
# Train Loss: 0.0178, Train Acc: 0.9538
# Val Loss: 0.7210, Val Acc: 0.8538
# Epoch 39/50
# Train Loss: 0.0158, Train Acc: 0.9549
# Val Loss: 0.7311, Val Acc: 0.8542
# Epoch 40/50
# Train Loss: 0.0126, Train Acc: 0.9560
# Val Loss: 0.7189, Val Acc: 0.8546
# Epoch 41/50
# Train Loss: 0.0100, Train Acc: 0.9570
# Val Loss: 0.7150, Val Acc: 0.8551
# Epoch 42/50
# Train Loss: 0.0083, Train Acc: 0.9580
# Val Loss: 0.7363, Val Acc: 0.8555
# Epoch 43/50
# Train Loss: 0.0078, Train Acc: 0.9589
# Val Loss: 0.7373, Val Acc: 0.8559
# Epoch 44/50
# Train Loss: 0.0067, Train Acc: 0.9598
# Val Loss: 0.7405, Val Acc: 0.8563
# Epoch 45/50
# Train Loss: 0.0061, Train Acc: 0.9607
# Val Loss: 0.7491, Val Acc: 0.8567
# Epoch 46/50
# Train Loss: 0.0051, Train Acc: 0.9615
# Val Loss: 0.7527, Val Acc: 0.8570
# Epoch 47/50
# Train Loss: 0.0050, Train Acc: 0.9623
# Val Loss: 0.7556, Val Acc: 0.8573
# Epoch 48/50
# Train Loss: 0.0070, Train Acc: 0.9631
# Val Loss: 0.7517, Val Acc: 0.8577
# Epoch 49/50
# Train Loss: 0.0046, Train Acc: 0.9638
# Val Loss: 0.7533, Val Acc: 0.8580
# Epoch 50/50
# Train Loss: 0.0039, Train Acc: 0.9645
# Val Loss: 0.7633, Val Acc: 0.8583

# %%
train_model(
    model=model,
    train_data=train_dataloader,
    valid_data=valid_dataloader
)
torch.save(model.state_dict(), 'waveform_encoder.pt')
# Out:
# Epoch 1/50
# Train Loss: 0.3065, Train Acc: 0.9041
# Val Loss: 0.5998, Val Acc: 0.8432
# Epoch 2/50
# Train Loss: 0.2419, Train Acc: 0.9133
# Val Loss: 0.5784, Val Acc: 0.8431
# Epoch 3/50
# Train Loss: 0.2396, Train Acc: 0.9161
# Val Loss: 0.5869, Val Acc: 0.8434
# Epoch 4/50
# Train Loss: 0.2221, Train Acc: 0.9191
# Val Loss: 0.5635, Val Acc: 0.8445
# Epoch 5/50
# Train Loss: 0.2120, Train Acc: 0.9214
# Val Loss: 0.5595, Val Acc: 0.8457
# Epoch 6/50
# Train Loss: 0.2055, Train Acc: 0.9234
# Val Loss: 0.5485, Val Acc: 0.8467
# Epoch 7/50
# Train Loss: 0.2002, Train Acc: 0.9249
# Val Loss: 0.5517, Val Acc: 0.8472
# Epoch 8/50
# Train Loss: 0.1911, Train Acc: 0.9265
# Val Loss: 0.5588, Val Acc: 0.8481
# Epoch 9/50
# Train Loss: 0.1807, Train Acc: 0.9281
# Val Loss: 0.5635, Val Acc: 0.8486
# Epoch 10/50
# Train Loss: 0.1697, Train Acc: 0.9298
# Val Loss: 0.5802, Val Acc: 0.8492
# Epoch 11/50
# Train Loss: 0.1700, Train Acc: 0.9311
# Val Loss: 0.5960, Val Acc: 0.8491
# Epoch 12/50
# Train Loss: 0.1710, Train Acc: 0.9321
# Val Loss: 0.5670, Val Acc: 0.8498
# Epoch 13/50
# Train Loss: 0.1389, Train Acc: 0.9338
# Val Loss: 0.5861, Val Acc: 0.8503
# Epoch 14/50
# Train Loss: 0.1336, Train Acc: 0.9354
# Val Loss: 0.5790, Val Acc: 0.8508
# Epoch 15/50
# Train Loss: 0.1285, Train Acc: 0.9370
# Val Loss: 0.5763, Val Acc: 0.8515
# Epoch 16/50
# Train Loss: 0.1230, Train Acc: 0.9384
# Val Loss: 0.5801, Val Acc: 0.8521
# Epoch 17/50
# Train Loss: 0.1307, Train Acc: 0.9396
# Val Loss: 0.5904, Val Acc: 0.8525
# Epoch 18/50
# Train Loss: 0.1231, Train Acc: 0.9407
# Val Loss: 0.5992, Val Acc: 0.8529
# Epoch 19/50
# Train Loss: 0.1141, Train Acc: 0.9418
# Val Loss: 0.5818, Val Acc: 0.8536
# Epoch 20/50
# Train Loss: 0.0912, Train Acc: 0.9432
# Val Loss: 0.6200, Val Acc: 0.8540
# Epoch 21/50
# Train Loss: 0.0824, Train Acc: 0.9447
# Val Loss: 0.6403, Val Acc: 0.8544
# Epoch 22/50
# Train Loss: 0.0949, Train Acc: 0.9458
# Val Loss: 0.6153, Val Acc: 0.8548
# Epoch 23/50
# Train Loss: 0.0836, Train Acc: 0.9470
# Val Loss: 0.6230, Val Acc: 0.8553
# Epoch 24/50
# Train Loss: 0.0753, Train Acc: 0.9482
# Val Loss: 0.6302, Val Acc: 0.8556
# Epoch 25/50
# Train Loss: 0.0694, Train Acc: 0.9494
# Val Loss: 0.6312, Val Acc: 0.8561
# Epoch 26/50
# Train Loss: 0.0592, Train Acc: 0.9506
# Val Loss: 0.6424, Val Acc: 0.8564
# Epoch 27/50
# Train Loss: 0.0542, Train Acc: 0.9518
# Val Loss: 0.6326, Val Acc: 0.8569
# Epoch 28/50
# Train Loss: 0.0500, Train Acc: 0.9530
# Val Loss: 0.6493, Val Acc: 0.8572
# Epoch 29/50
# Train Loss: 0.0466, Train Acc: 0.9541
# Val Loss: 0.6724, Val Acc: 0.8576
# Epoch 30/50
# Train Loss: 0.0449, Train Acc: 0.9552
# Val Loss: 0.6819, Val Acc: 0.8580
# Epoch 31/50
# Train Loss: 0.0449, Train Acc: 0.9562
# Val Loss: 0.6630, Val Acc: 0.8584
# Epoch 32/50
# Train Loss: 0.0464, Train Acc: 0.9571
# Val Loss: 0.6301, Val Acc: 0.8588
# Epoch 33/50
# Train Loss: 0.0343, Train Acc: 0.9581
# Val Loss: 0.6764, Val Acc: 0.8593
# Epoch 34/50
# Train Loss: 0.0230, Train Acc: 0.9591
# Val Loss: 0.6780, Val Acc: 0.8597
# Epoch 35/50
# Train Loss: 0.0164, Train Acc: 0.9602
# Val Loss: 0.6770, Val Acc: 0.8603
# Epoch 36/50
# Train Loss: 0.0142, Train Acc: 0.9612
# Val Loss: 0.6866, Val Acc: 0.8607
# Epoch 37/50
# Train Loss: 0.0131, Train Acc: 0.9621
# Val Loss: 0.7058, Val Acc: 0.8611
# Epoch 38/50
# Train Loss: 0.0138, Train Acc: 0.9630
# Val Loss: 0.6997, Val Acc: 0.8615
# Epoch 39/50
# Train Loss: 0.0119, Train Acc: 0.9639
# Val Loss: 0.6963, Val Acc: 0.8619
# Epoch 40/50
# Train Loss: 0.0101, Train Acc: 0.9648
# Val Loss: 0.6962, Val Acc: 0.8623
# Epoch 41/50
# Train Loss: 0.0078, Train Acc: 0.9656
# Val Loss: 0.7195, Val Acc: 0.8627
# Epoch 42/50
# Train Loss: 0.0061, Train Acc: 0.9664
# Val Loss: 0.7212, Val Acc: 0.8631
# Epoch 43/50
# Train Loss: 0.0052, Train Acc: 0.9671
# Val Loss: 0.7161, Val Acc: 0.8634
# Epoch 44/50
# Train Loss: 0.0049, Train Acc: 0.9679
# Val Loss: 0.7270, Val Acc: 0.8638
# Epoch 45/50
# Train Loss: 0.0042, Train Acc: 0.9686
# Val Loss: 0.7229, Val Acc: 0.8641
# Epoch 46/50
# Train Loss: 0.0039, Train Acc: 0.9692
# Val Loss: 0.7398, Val Acc: 0.8644
# Epoch 47/50
# Train Loss: 0.0036, Train Acc: 0.9699
# Val Loss: 0.7395, Val Acc: 0.8647
# Epoch 48/50
# Train Loss: 0.0031, Train Acc: 0.9705
# Val Loss: 0.7404, Val Acc: 0.8650
# Epoch 49/50
# Train Loss: 0.0029, Train Acc: 0.9711
# Val Loss: 0.7522, Val Acc: 0.8652
# Epoch 50/50
# Train Loss: 0.0026, Train Acc: 0.9716
# Val Loss: 0.7553, Val Acc: 0.8655

# %%
df_test = pd.read_csv(
    os.path.join(TEST_DIR_PATH, 'metadata.csv')
)
test_dataloader = DataLoader(
    SpeechCommandDataset(
        dir_path=TEST_DIR_PATH,
        data=df_test.file_name.values,
        labels=None,
        dict_label_to_index=dict_label_to_index,
        transform=torchaudio.transforms.MFCC(n_mfcc=N_MFCC, log_mels=True),
        noise_amplitude=0.0
    ),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=N_WORKERS
)

# %%
# ENSEMBLE PREDICTIONS AND SUBMIT
results = {
    'id': [],
    'label': []
}

model.eval()
for x, x_sp, y, ids in test_dataloader:
    x = x.to(DEVICE)
    x_sp = x_sp.to(DEVICE)
    with torch.no_grad():
        y_hat = model(x).squeeze()
        _, preds = torch.max(y_hat, 1)
        for i in range(len(preds)):
            results["id"].append(ids[i].item())
            results["label"].append(dict_index_to_label[int(preds[i].item())])
        

pd.DataFrame(results).to_csv(
    'submission_waveform_encoder.csv',
    columns=['id', 'label'],
    index=False
)
