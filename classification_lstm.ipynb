# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import os

import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
import torchaudio
import torchmetrics
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset

# %%
TRAIN_DIR_PATH = 'voice-commands-classification-2025/train'
TEST_DIR_PATH = 'voice-commands-classification-2025/adv_test'

# %%
BATCH_SIZE = 512
N_WORKERS = 6
N_CLASSES = 35
EPOCHS = 50
LR = 0.01

N_MFCC = 120
NOISE_AMPLITUDE = 0.000
MASK_PROB = 0.1

DEVICE = torch.device('cpu')
if torch.cuda.is_available():
    DEVICE = torch.device('cuda:0')
elif torch.backends.mps.is_available():
    DEVICE = torch.device('mps')

DEVICE
# Out:
# device(type='cuda', index=0)

# %%
# Dataset

def noise_waveform(waveform: torch.Tensor, noise_amplitude: float = 0.05) -> torch.Tensor:
    noise = noise_amplitude * torch.randn(waveform.shape).to(waveform.device)
    noisy_waveform = waveform + noise
    noisy_waveform = torch.clamp(noisy_waveform, -1.0, 1.0)
    return noisy_waveform

class SpeechCommandDataset(Dataset):
    def __init__(self, dir_path, data, labels=None, dict_label_to_index=None, transform=None, noise_amplitude=0.00):
        self.dir_path = dir_path
        self.data = data
        self.labels = labels
        self.dict_label_to_index = dict_label_to_index
        self.transform = transform
        self.noise_amplitude = noise_amplitude

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        file_name = self.data[idx]
        waveform = np.load(os.path.join(self.dir_path, file_name))
        if waveform.shape[1] < 16000:
            waveform = np.pad(
                waveform, pad_width=((0, 0), (0, 16000 - waveform.shape[1])),
                mode='constant',
                constant_values=0
            )

        waveform = torch.from_numpy(waveform).float()

        if self.transform != None:
            spectrogram = self.transform(waveform)
        else:
            spectrogram = None

        if self.noise_amplitude > 0:
            waveform = noise_waveform(waveform, self.noise_amplitude)
        
        out_labels = []
        if self.labels is not None:
            if self.labels[idx] in self.dict_label_to_index:
                out_labels = self.dict_label_to_index[self.labels[idx]]

        return waveform, spectrogram, out_labels, int(file_name.split('.')[0])

# %%
df_train = pd.read_csv(
    os.path.join(TRAIN_DIR_PATH, 'metadata.csv')
)
dict_label_to_index = {}
dict_index_to_label = {}
for index, key in enumerate(df_train['label'].unique()):
    dict_label_to_index[key] = index
    dict_index_to_label[index] = key

dict_label_to_index
# Out:
# {'stop': 0,
#  'go': 1,
#  'right': 2,
#  'dog': 3,
#  'left': 4,
#  'yes': 5,
#  'zero': 6,
#  'four': 7,
#  'bird': 8,
#  'cat': 9,
#  'five': 10,
#  'off': 11,
#  'learn': 12,
#  'six': 13,
#  'two': 14,
#  'on': 15,
#  'up': 16,
#  'three': 17,
#  'nine': 18,
#  'one': 19,
#  'follow': 20,
#  'wow': 21,
#  'seven': 22,
#  'sheila': 23,
#  'down': 24,
#  'no': 25,
#  'bed': 26,
#  'eight': 27,
#  'house': 28,
#  'tree': 29,
#  'visual': 30,
#  'forward': 31,
#  'marvin': 32,
#  'backward': 33,
#  'happy': 34}

# %%
df_train_data, df_val_data = train_test_split(
    df_train,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

train_data = df_train_data.file_name.values
train_labels = df_train_data.label.values

val_data = df_val_data.file_name.values
val_labels = df_val_data.label.values

# %%
# DataLoader, transform

train_dataloader = DataLoader(
    SpeechCommandDataset(
        dir_path=TRAIN_DIR_PATH,
        data=train_data,
        labels=train_labels,
        dict_label_to_index=dict_label_to_index,
        transform=torchaudio.transforms.MFCC(n_mfcc=N_MFCC, log_mels=True),
        noise_amplitude=NOISE_AMPLITUDE
    ),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=N_WORKERS
)

valid_dataloader = DataLoader(
    SpeechCommandDataset(
        dir_path=TRAIN_DIR_PATH,
        data=val_data,
        labels=val_labels,
        dict_label_to_index=dict_label_to_index,
        transform=torchaudio.transforms.MFCC(n_mfcc=N_MFCC, log_mels=True),
        noise_amplitude=0.0
    ),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=N_WORKERS
)

# %%
for item in train_dataloader:
    print(item[0].shape, item[1].shape)
    break
# Out:
# torch.Size([512, 1, 16000]) torch.Size([512, 1, 120, 81])

# %%
class M5(nn.Module):
    def __init__(self, n_input, n_output, stride=160, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=400, stride=stride)
        self.bn1 = nn.BatchNorm1d(n_channel)
        self.lstm = nn.LSTM(n_channel, n_channel, num_layers=2, batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(2 * n_channel, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = x.transpose(-1, -2)
        x, _ = self.lstm(x)
        x = x.transpose(-1, -2)
        x = F.avg_pool1d(x, x.shape[-1])
        x = x.transpose(-1, -2)
        x = self.fc1(x)
        return F.log_softmax(x, dim=2)

# %%
model = M5(n_input=1, n_output=35, stride=160, n_channel=N_MFCC)
model = model.to(DEVICE)

# %%
input_image = torch.rand(4, 1, 16000).to(DEVICE)
model = model.to(DEVICE)
result = model(input_image)
print(result.size())
# Out:
# torch.Size([4, 1, 35])

# %%
def lr_lambda(current_step):
    return max(0.0, float(EPOCHS - current_step) / EPOCHS)


def train_model(model: nn.Module, train_data: DataLoader, valid_data: DataLoader):
    optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=2e-5)
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
    criterion = nn.NLLLoss()

    accuracy_train = torchmetrics.classification.Accuracy(task="multiclass", num_classes=N_CLASSES).to(DEVICE)
    accuracy_val = torchmetrics.classification.Accuracy(task="multiclass", num_classes=N_CLASSES).to(DEVICE)

    for epoch in range(EPOCHS):
        train_loss = 0.0
        val_loss = 0.0

        model.train()
        for x, x_sp, y, _ in train_data:
            x = x.to(DEVICE)
            x_sp = x_sp.to(DEVICE)
            y = y.to(DEVICE)

            optimizer.zero_grad()

            y_hat = model(x).squeeze()
            loss = criterion(y_hat, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item() * x.size(0)
            _, preds = torch.max(y_hat, 1)

            accuracy_train(
                y_hat,
                y
            )

        model.eval()
        for x, x_sp, y, _ in valid_data:
            x = x.to(DEVICE)
            x_sp = x_sp.to(DEVICE)
            y = y.to(DEVICE)

            y_hat = model(x).squeeze()
            loss = criterion(y_hat, y)

            val_loss += loss.item() * x.size(0)
            _, preds = torch.max(y_hat, 1)

            accuracy_val(
                y_hat,
                y
            )

        train_loss = train_loss / len(train_dataloader.dataset)
        val_loss = val_loss / len(valid_dataloader.dataset)

        scheduler.step()

        print(f"Epoch {epoch + 1}/{EPOCHS}")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {accuracy_train.compute():.4f}")
        print(f"Val Loss: {val_loss:.4f}, Val Acc: {accuracy_val.compute():.4f}")

# %%
train_model(
    model=model,
    train_data=train_dataloader,
    valid_data=valid_dataloader
)
torch.save(model.state_dict(), 'waveform_encoder_1.pt')

# %%
train_model(
    model=model,
    train_data=train_dataloader,
    valid_data=valid_dataloader
)
# Out:
# Epoch 1/50
# Train Loss: 0.3976, Train Acc: 0.8744
# Val Loss: 0.5840, Val Acc: 0.8265
# Epoch 2/50
# Train Loss: 0.3441, Train Acc: 0.8824
# Val Loss: 0.5916, Val Acc: 0.8257
# Epoch 3/50
# Train Loss: 0.3354, Train Acc: 0.8859
# Val Loss: 0.5663, Val Acc: 0.8282
# Epoch 4/50
# Train Loss: 0.3154, Train Acc: 0.8893
# Val Loss: 0.5426, Val Acc: 0.8314
# Epoch 5/50
# Train Loss: 0.3033, Train Acc: 0.8918
# Val Loss: 0.5453, Val Acc: 0.8329
# Epoch 6/50
# Train Loss: 0.3064, Train Acc: 0.8935
# Val Loss: 0.5485, Val Acc: 0.8341
# Epoch 7/50
# Train Loss: 0.2812, Train Acc: 0.8956
# Val Loss: 0.5351, Val Acc: 0.8349
# Epoch 8/50
# Train Loss: 0.2824, Train Acc: 0.8974
# Val Loss: 0.5422, Val Acc: 0.8357
# Epoch 9/50
# Train Loss: 0.2712, Train Acc: 0.8991
# Val Loss: 0.5377, Val Acc: 0.8364
# Epoch 10/50
# Train Loss: 0.2961, Train Acc: 0.8998
# Val Loss: 0.5165, Val Acc: 0.8375
# Epoch 11/50
# Train Loss: 0.2462, Train Acc: 0.9018
# Val Loss: 0.5164, Val Acc: 0.8387
# Epoch 12/50
# Train Loss: 0.2380, Train Acc: 0.9037
# Val Loss: 0.5092, Val Acc: 0.8398
# Epoch 13/50
# Train Loss: 0.2183, Train Acc: 0.9056
# Val Loss: 0.5285, Val Acc: 0.8405
# Epoch 14/50
# Train Loss: 0.1978, Train Acc: 0.9079
# Val Loss: 0.5250, Val Acc: 0.8412
# Epoch 15/50
# Train Loss: 0.1972, Train Acc: 0.9098
# Val Loss: 0.5035, Val Acc: 0.8424
# Epoch 16/50
# Train Loss: 0.1914, Train Acc: 0.9117
# Val Loss: 0.4962, Val Acc: 0.8435
# Epoch 17/50
# Train Loss: 0.1731, Train Acc: 0.9136
# Val Loss: 0.5174, Val Acc: 0.8444
# Epoch 18/50
# Train Loss: 0.1603, Train Acc: 0.9155
# Val Loss: 0.5213, Val Acc: 0.8450
# Epoch 19/50
# Train Loss: 0.1574, Train Acc: 0.9173
# Val Loss: 0.5200, Val Acc: 0.8456
# Epoch 20/50
# Train Loss: 0.1474, Train Acc: 0.9191
# Val Loss: 0.5219, Val Acc: 0.8463
# Epoch 21/50
# Train Loss: 0.1369, Train Acc: 0.9209
# Val Loss: 0.5386, Val Acc: 0.8470
# Epoch 22/50
# Train Loss: 0.1199, Train Acc: 0.9228
# Val Loss: 0.5165, Val Acc: 0.8477
# Epoch 23/50
# Train Loss: 0.1163, Train Acc: 0.9246
# Val Loss: 0.5340, Val Acc: 0.8482
# Epoch 24/50
# Train Loss: 0.1053, Train Acc: 0.9264
# Val Loss: 0.5321, Val Acc: 0.8486
# Epoch 25/50
# Train Loss: 0.0962, Train Acc: 0.9282
# Val Loss: 0.5315, Val Acc: 0.8491
# Epoch 26/50
# Train Loss: 0.0926, Train Acc: 0.9299
# Val Loss: 0.5257, Val Acc: 0.8496
# Epoch 27/50
# Train Loss: 0.0808, Train Acc: 0.9316
# Val Loss: 0.5299, Val Acc: 0.8502
# Epoch 28/50
# Train Loss: 0.0671, Train Acc: 0.9334
# Val Loss: 0.5360, Val Acc: 0.8508
# Epoch 29/50
# Train Loss: 0.0597, Train Acc: 0.9351
# Val Loss: 0.5412, Val Acc: 0.8513
# Epoch 30/50
# Train Loss: 0.0571, Train Acc: 0.9368
# Val Loss: 0.5367, Val Acc: 0.8519
# Epoch 31/50
# Train Loss: 0.0468, Train Acc: 0.9384
# Val Loss: 0.5417, Val Acc: 0.8524
# Epoch 32/50
# Train Loss: 0.0451, Train Acc: 0.9400
# Val Loss: 0.5456, Val Acc: 0.8528
# Epoch 33/50
# Train Loss: 0.0457, Train Acc: 0.9414
# Val Loss: 0.5443, Val Acc: 0.8533
# Epoch 34/50
# Train Loss: 0.0436, Train Acc: 0.9428
# Val Loss: 0.5528, Val Acc: 0.8537
# Epoch 35/50
# Train Loss: 0.0410, Train Acc: 0.9442
# Val Loss: 0.5674, Val Acc: 0.8541
# Epoch 36/50
# Train Loss: 0.0367, Train Acc: 0.9455
# Val Loss: 0.5503, Val Acc: 0.8545
# Epoch 37/50
# Train Loss: 0.0262, Train Acc: 0.9468
# Val Loss: 0.5411, Val Acc: 0.8550
# Epoch 38/50
# Train Loss: 0.0195, Train Acc: 0.9481
# Val Loss: 0.5436, Val Acc: 0.8556
# Epoch 39/50
# Train Loss: 0.0154, Train Acc: 0.9494
# Val Loss: 0.5472, Val Acc: 0.8561
# Epoch 40/50
# Train Loss: 0.0163, Train Acc: 0.9506
# Val Loss: 0.5534, Val Acc: 0.8567
# Epoch 41/50
# Train Loss: 0.0128, Train Acc: 0.9517
# Val Loss: 0.5609, Val Acc: 0.8571
# Epoch 42/50
# Train Loss: 0.0124, Train Acc: 0.9528
# Val Loss: 0.5633, Val Acc: 0.8576
# Epoch 43/50
# Train Loss: 0.0129, Train Acc: 0.9538
# Val Loss: 0.5752, Val Acc: 0.8579
# Epoch 44/50
# Train Loss: 0.0133, Train Acc: 0.9548
# Val Loss: 0.5683, Val Acc: 0.8584
# Epoch 45/50
# Train Loss: 0.0124, Train Acc: 0.9558
# Val Loss: 0.5844, Val Acc: 0.8587
# Epoch 46/50
# Train Loss: 0.0114, Train Acc: 0.9567
# Val Loss: 0.5664, Val Acc: 0.8591
# Epoch 47/50
# Train Loss: 0.0084, Train Acc: 0.9576
# Val Loss: 0.5725, Val Acc: 0.8595
# Epoch 48/50
# Train Loss: 0.0070, Train Acc: 0.9585
# Val Loss: 0.5706, Val Acc: 0.8598
# Epoch 49/50
# Train Loss: 0.0064, Train Acc: 0.9593
# Val Loss: 0.5778, Val Acc: 0.8601
# Epoch 50/50
# Train Loss: 0.0059, Train Acc: 0.9601
# Val Loss: 0.5806, Val Acc: 0.8605

# %%
torch.save(model.state_dict(), 'waveform_encoder_2.pt')

# %%
df_test = pd.read_csv(
    os.path.join(TEST_DIR_PATH, 'metadata.csv')
)
test_dataloader = DataLoader(
    SpeechCommandDataset(
        dir_path=TEST_DIR_PATH,
        data=df_test.file_name.values,
        labels=None,
        dict_label_to_index=dict_label_to_index,
        transform=torchaudio.transforms.MFCC(n_mfcc=N_MFCC, log_mels=True),
        noise_amplitude=0.0
    ),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=N_WORKERS
)

# %%
# ENSEMBLE PREDICTIONS AND SUBMIT
results = {
    'id': [],
    'label': []
}

model.eval()
for x, x_sp, y, ids in test_dataloader:
    x = x.to(DEVICE)
    x_sp = x_sp.to(DEVICE)
    with torch.no_grad():
        y_hat = model(x).squeeze()
        _, preds = torch.max(y_hat, 1)
        for i in range(len(preds)):
            results["id"].append(ids[i].item())
            results["label"].append(dict_index_to_label[int(preds[i].item())])
        

pd.DataFrame(results).to_csv(
    'submission_waveform_encoder.csv',
    columns=['id', 'label'],
    index=False
)
